# %%
import numpy as np
import torch
import fusecam
from fusecam.aiutil.ensembling import construct_3dsms_ensembler
import matplotlib.pyplot as plt

# %%
for layers in range(5,21,1):
    pcount = construct_3dsms_ensembler(100,1,1,
                               layers,
                               alpha = 0.5,
                               gamma = 0.0,
                               hidden_channels = [3],
                               parameter_bounds = None,
                               parameter_counts_only = True
                               )
    plt.hist(pcount)
    plt.title("Layers %i"%layers)
    plt.show()
